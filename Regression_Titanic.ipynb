# %%
#
#
#IMPORTANT: code coppied from Machine_Learning_Code/S04/code_4/Regression_Diamonds.ipynb
#
import pandas as pd
from math import sqrt
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from os import getcwd
print('hello')
print(getcwd())
print('#############')
# Out:
# hello
# /home/homayoun-yousefi/programming/proj/A
# #############

# %% [markdown]
# price   : price in US dollars (326 $  - 18,823 $)
# carat   : weight of the diamond (0.2 - 5.01)
# cut     : quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# color   : diamond colour, from J (worst) to D (best)  :JIHGFED
# clarity : a measurement of how clear the diamond is (I1 (worst) , SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# x       : length in mm (0 - 10.74)
# y       : width in mm (0 - 58.9)
# z       : depth in mm (0 - 31.8)

# %%
d = pd.read_csv("train_dataset/4.csv", index_col = None)
d.shape
# Out:
# (891, 7)

# %%
d.head(7)
# Out:
#      Pclass       Sex       Age     SibSp     Parch  Embarked  Survived
# 0  0.001458  0.000000  0.000905  0.002146  0.000000  0.001464  0.000000
# 1  0.000486  0.003185  0.001562  0.002146  0.000000  0.000000  0.002924
# 2  0.001458  0.003185  0.001069  0.000000  0.000000  0.001464  0.002924
# 3  0.000486  0.003185  0.001439  0.002146  0.000000  0.001464  0.002924
# 4  0.001458  0.000000  0.001439  0.000000  0.000000  0.001464  0.000000
# 5  0.000486  0.000000  0.002220  0.000000  0.000000  0.001464  0.000000
# 6  0.001458  0.000000  0.000082  0.006438  0.002941  0.001464  0.000000

# %% [markdown]
# #Preprocess

# %%
d.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch    Embarked  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.001122    0.001122    0.001122    0.001122    0.001122    0.001122
# std      0.000406    0.001522    0.000738    0.002366    0.002371    0.000581
# min      0.000486    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000972    0.000000    0.000658    0.000000    0.000000    0.000732
# 50%      0.001458    0.000000    0.001069    0.000000    0.000000    0.001464
# 75%      0.001458    0.003185    0.001562    0.002146    0.000000    0.001464
# max      0.001458    0.003185    0.003289    0.017167    0.017647    0.001464
#
#          Survived
# count  891.000000
# mean     0.001122
# std      0.001423
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.002924
# max      0.002924

# %%
X = d.loc[:,(d.columns != 'Survived')]  
Y = d.Survived

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.30, random_state = 1)
X_train.shape
# Out:
# (623, 6)

# %%
X_test.shape
# Out:
# (268, 6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Training with All Features 
model = LinearRegression()

# %%
new_X_train = X_train.loc[:,]
new_X_test  = X_test.loc [:,]

# %%
model.fit(new_X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(new_X_test)

# %%
mean_absolute_error(Y_test, Y_pred)
# Out:
# 0.0008546296761409426

# %%
sqrt(mean_squared_error(Y_test,Y_pred))
# Out:
# 0.0010957862274845003
